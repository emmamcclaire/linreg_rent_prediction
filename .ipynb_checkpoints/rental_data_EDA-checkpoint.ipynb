# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
with open('alameda_county_data_200114.pickle','rb') as read_file:
    df = pickle.load(read_file)

# %%
df.head()
# Out:
#          City    Zip   Neighborhood            Address_1  Address_2   Price  \
# 0     Oakland  94618      Parkwoods   240 Caldecott Lane   Unit 314  2500.0
# 1      Albany  94706       Hillside   625 Jackson Street     Unit 2  2850.0
# 2  Emeryville  94608   North Hollis     1254 65th Street        N/A  4250.0
# 3    Berkeley  94702  Poet's Corner  1338 Addison Street        N/A  2375.0
# 4  Emeryville  94608      Watergate       4 Anchor Drive  Unit F241  2275.0
#
#    Beds  Baths  Half_Baths Sq_Footage  ...  Half_Baths       MLS #  Furnished  \
# 0   1.0    1.0         0.0        773  ...         0.0      511967          -
# 1   2.0    2.0         0.0       1112  ...         0.0  40933893BR          -
# 2   2.0    2.0         1.0       1296  ...         1.0    40932990          -
# 3   2.0    1.0         0.0        600  ...         0.0  40933389BR          -
# 4   1.0    1.0         0.0        660  ...         0.0    40933210          -
#
# ...

# %%
df.Price.describe()
# Out:
#               Price         Price
# count  1.900000e+02  1.900000e+02
# mean   2.276953e+04  2.276953e+04
# std    2.718376e+05  2.718376e+05
# min    1.000000e+00  1.000000e+00
# 25%    2.295000e+03  2.295000e+03
# 50%    2.625000e+03  2.625000e+03
# 75%    3.398750e+03  3.398750e+03
# max    3.750000e+06  3.750000e+06

# %%
sns.histplot(data = df, x = 'Price')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-51ad04616bb9> in <module>
# ----> 1 sns.histplot(data = df, x = 'Price')
#
# AttributeError: module 'seaborn' has no attribute 'histplot'
