# %%
import pandas as pd
import numpy as np
import pickle

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
with open('pickles/cleaned_210115_data_laundry_revised_add_ws.pickle', 'rb') as read_file:
    df = pickle.load(read_file)

# %%
sns.histplot(data = df, x = 'beds')
# Out:
# <AxesSubplot:xlabel='beds', ylabel='Count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1209 entries, 0 to 1692
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   city             1209 non-null   string
#  1   zip              1209 non-null   string
#  2   neighborhood     1209 non-null   string
#  3   address_1        1209 non-null   string
#  4   address_2        1209 non-null   string
#  5   price            1209 non-null   float64
#  6   beds             1209 non-null   float64
#  7   baths            1209 non-null   float64
#  8   half_baths       1209 non-null   float64
#  9   sq_footage       1209 non-null   int64
#  10  mls_num          1209 non-null   string
#  11  furnished        1209 non-null   string
#  12  mls_type         1209 non-null   string
#  13  year_built       1209 non-null   float64
#  14  county           1200 non-null   string
#  15  laundry_type     1209 non-null   object
# ...

# %%
df.head()
# Out:
#          city    zip   neighborhood            address_1  address_2   price  \
# 0     Oakland  94618      Parkwoods   240 Caldecott Lane   Unit 314  2500.0
# 1      Albany  94706       Hillside   625 Jackson Street     Unit 2  2850.0
# 2  Emeryville  94608   North Hollis     1254 65th Street        N/A  4250.0
# 3    Berkeley  94702  Poet's Corner  1338 Addison Street        N/A  2375.0
# 4  Emeryville  94608      Watergate       4 Anchor Drive  Unit F241  2275.0
#
#    beds  baths  half_baths  sq_footage  ... year_built          county  \
# 0   1.0    1.0         0.0         773  ...     1996.0  Alameda County
# 1   2.0    2.0         0.0        1112  ...     1972.0  Alameda County
# 2   2.0    2.0         1.0        1296  ...     2003.0  Alameda County
# 3   2.0    1.0         0.0         600  ...     1972.0  Alameda County
# 4   1.0    1.0         0.0         660  ...     1973.0  Alameda County
#
#     laundry_type  laundry_snippet    parking_spots  \
# ...

# %%
#drop some colinears and non-useful features
df = df.drop(['baths', 'half_baths', 'county'], axis = 1)

# %%
sns.pairplot(df);

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df.corr(), cmap="seismic", vmin=-1, vmax=1, ax=ax);

# %% [markdown]
# ---
#
# **attempt 1: basic model, no feature engineering, no additional data cleaning**
#
# ---

# %%
df.columns
# Out:
# Index(['city', 'zip', 'neighborhood', 'address_1', 'address_2', 'price',
#        'beds', 'sq_footage', 'mls_num', 'furnished', 'mls_type', 'year_built',
#        'laundry_type', 'laundry_snippet', 'parking_spots', 'parking_snippet',
#        'has_address_2', 'baths_incl_half', 'clean_mls_types', 'walk_score'],
#       dtype='object')

# %%
X = df[['city',
       'beds', 'sq_footage', 'year_built', 'laundry_type',
       'parking_spots', 'has_address_2', 'baths_incl_half',
       'clean_mls_types', 'walk_score']]

y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 25)
print(X_train.shape, X_test.shape)
# Out:
# (967, 10) (242, 10)

# %% [markdown]
# ![image.png](attachment:7ede6da8-1a68-4bf0-a3e2-b32e11d37d78.png)

# %%
num_feats = ['beds', 'sq_footage', 'year_built',
                   'has_address_2', 'baths_incl_half', 'walk_score']
cat_feats = ['city', 'parking_spots', 'clean_mls_types', 'laundry_type']

num_feats_df = X_train[num_feats]
cat_feats_df = X_train[cat_feats]

# %%
ohe = OneHotEncoder(drop='first', sparse=False)
feature_arr = ohe.fit_transform(cat_feats_df)
feature_labels = ohe.get_feature_names(cat_feats)
cat_feats_ohe = pd.DataFrame(data = feature_arr, 
                             columns=feature_labels,
                            index = num_feats_df.index)

# %%
combined_X_train = pd.concat([num_feats_df, cat_feats_ohe], axis = 1)

# %%
lr = LinearRegression()
lr.fit(combined_X_train, y_train)
predicted_y_values = lr.predict(combined_X_train)
print('lr version 1')
print('- - - - - - - - - - - - - - - - - - - - - - -')
print('rmse: ', np.sqrt(mean_squared_error(y_train, predicted_y_values)))
print('r2: ', r2_score(y_train, predicted_y_values))
# Out:
# lr version 1
# - - - - - - - - - - - - - - - - - - - - - - -
# rmse:  1204.5155100210259
# r2:  0.6729420073812676

# %% [markdown]
# ---
#
# **attempt 2: look more closely at some of the features to see what mods can be made**
#
# ---

# %%
sns.scatterplot(data = df, x = 'walk_score', y = 'price');

# %%
fig, ax = plt.subplots(figsize=(10, 5))
g = sns.scatterplot(data = df, x = 'sq_footage', y = 'price');

ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.title.set_color('white')

plt.ylabel('Rent Price ($)', fontsize = 15)
plt.xlabel('Square Footage', fontsize = 15)
plt.title('Square Footage by Rent Price', fontsize = 20)
g.figure.savefig('squareft.svg')

# %% [markdown]
# This scatterplot of walk score by price is not nearly as predictive as I had thought. It looks like some of the higher square footage data points (darker purple) account for many of the high price outliers.

# %%
sq_max_ls = []
score_ls = []
df_len = []
max_score = [0, 0]
for sq_max in range(1000, 6000, 300):  
    sq_max_ls.append(sq_max)
    df_sq = df[df.sq_footage < sq_max]
    
    X = df_sq[['beds', 'sq_footage', 'year_built',
                   'has_address_2', 'baths_incl_half', 'walk_score']]
    y = df_sq['price']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 25)
    
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    score = lr.score(X_train, y_train)
    score_ls.append(score)
    df_len.append(df_sq.shape[0])
    if score > max_score[0]:
        max_score = [score, sq_max]
print('max_score: ', max_score[0], '\nfilter: df[df.sq_footage <', max_score[1],']')
# Out:
# max_score:  0.5833056426295828
# filter: df[df.sq_footage < 3100 ]

# %%
fig, ax = plt.subplots(figsize=(10, 7))
g = sns.lineplot(x = sq_max_ls, y = score_ls);

ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.title.set_color('white')

plt.title('R^2 for Range of Square Footage Maximum Values', fontsize = 15);
plt.xlabel('Max Square Footage Included in Training Dataset', fontsize = 12);
plt.ylabel('R^2', fontsize = 12);
g.figure.savefig('squareft.png')

# %%
from sklearn.model_selection import cross_val_score

def get_cv_r2s(model, X, y):
    cv_r2s = cross_val_score(model, X, y, cv=5, scoring = 'r2')
    mean_r2 = np.mean(cv_r2s)
    return mean_r2

sq_max_ls = []
score_ls = []
df_len = []
max_score = [0, 0]
for sq_max in range(1000, 6000, 300):  
    sq_max_ls.append(sq_max)
    df_sq = df[df.sq_footage < sq_max]
    
    X = df_sq[['beds', 'sq_footage', 'year_built',
                   'has_address_2', 'baths_incl_half', 'walk_score']]
    y = df_sq['price']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 25)
    
    lr = LinearRegression()
    score = get_cv_r2s(lr, X_train, y_train)
    
    
    score_ls.append(score)
    
    df_len.append(df_sq.shape[0])
    if score > max_score[0]:
        max_score = [score, sq_max]
        
print('max_score: ', max_score[0], '\nfilter: df[df.sq_footage <', max_score[1],']')
# Out:
# max_score:  0.5542189542139206
# filter: df[df.sq_footage < 3100 ]

# %%
fig, ax = plt.subplots(figsize=(7, 7))
g = sns.lineplot(x = sq_max_ls, y = score_ls);

ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.title.set_color('white')

plt.title('R^2 for Range of Square Footage Maximum Values', fontsize = 15);
plt.xlabel('Max Square Footage Included in Training Dataset', fontsize = 12);
plt.ylabel('R^2', fontsize = 12);
g.figure.savefig('squareft.png')

# %%
# apply maximum sq footage filter at 3800 square feet
dp_before = df.shape[0]
df = df[df.sq_footage <= 3100]
dp_after = df.shape[0]
print(dp_before - dp_after, 'datapoints dropped')
# Out:
# 40 datapoints dropped

# %%
X = df[['city',
       'beds', 'sq_footage', 'year_built', 'laundry_type',
       'parking_spots', 'has_address_2', 'baths_incl_half',
       'clean_mls_types', 'mls_num', 'walk_score']]

y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 25)

num_feats = X_train[['beds', 'sq_footage', 'year_built',
                   'has_address_2', 'baths_incl_half', 'walk_score']]
cat_feats = X_train[['city', 'parking_spots', 'clean_mls_types', 'laundry_type']]

ohe = OneHotEncoder(drop='first', sparse=False)
feature_arr = ohe.fit_transform(cat_feats)
feature_labels = ohe.get_feature_names(['city', 'parking_spots', 'clean_mls_types', 'laundry_type'])
cat_feats_ohe = pd.DataFrame(data = feature_arr, columns=feature_labels,
                            index = num_feats.index)

combined_X_train = pd.concat([num_feats, cat_feats_ohe], axis = 1)

lr = LinearRegression()
lr.fit(combined_X_train, y_train)
predicted_y_values = lr.predict(combined_X_train)
print('lr version 2')
print('- - - - - - - - - - - - - - - - - - - - - - -')
print('rmse: ', np.sqrt(mean_squared_error(y_train, predicted_y_values)))
print('r2: ', r2_score(y_train, predicted_y_values))
# Out:
# lr version 2
# - - - - - - - - - - - - - - - - - - - - - - -
# rmse:  970.1673991755925
# r2:  0.6876887634324316

# %% [markdown]
# ---
#
# **attempt 3: feature engineering**
#
# ---

# %%
sns.pairplot(df);

# %%
combined_X_train_eng = combined_X_train.copy()
combined_X_train_eng['walk_score_sq_footage'] = combined_X_train['walk_score']*combined_X_train['sq_footage']
combined_X_train_eng['walk_score_year_built'] = combined_X_train['walk_score']*combined_X_train['year_built']
combined_X_train_eng['mls_type_year_built'] = combined_X_train['clean_mls_types_house']*combined_X_train['year_built']
combined_X_train_eng['beds_baths'] = combined_X_train['beds']*combined_X_train['baths_incl_half']
combined_X_train_eng['walk_score_walk_score'] = combined_X_train['walk_score']**3
combined_X_train_eng['beds_walk_score'] = combined_X_train['walk_score']*combined_X_train['beds']
combined_X_train_eng['address_2_walk_score'] = combined_X_train['walk_score']*combined_X_train['has_address_2']
combined_X_train_eng['year_built_address_2'] = combined_X_train['year_built']*combined_X_train['has_address_2']
#added after looking at residual plot
combined_X_train_eng['beds_beds_beds'] = combined_X_train['beds']**3
#combined_X_train_eng['beds_beds'] = combined_X_train['beds']**2

# this should probably be done in the cleaning and eda notebook
combined_X_train_eng['clean_mls_types_house'] = combined_X_train['clean_mls_types_house']+combined_X_train['clean_mls_types_single-family']
combined_X_train_eng = combined_X_train_eng.drop(['clean_mls_types_house', 'clean_mls_types_single-family'], axis = 1)

# %%
combined_X_train_eng.columns
# Out:
# Index(['beds', 'sq_footage', 'year_built', 'has_address_2', 'baths_incl_half',
#        'walk_score', 'city_Albany', 'city_Atherton', 'city_Belmont',
#        'city_Berkeley', 'city_Brisbane', 'city_Burlingame', 'city_Campbell',
#        'city_Castro Valley', 'city_Cupertino', 'city_Daly City', 'city_Dublin',
#        'city_East Palo Alto', 'city_Emeryville', 'city_Foster City',
#        'city_Fremont', 'city_Gilroy', 'city_Half Moon Bay', 'city_Hayward',
#        'city_Hillsborough', 'city_La Honda', 'city_Livermore',
#        'city_Los Altos', 'city_Los Gatos', 'city_Menlo Park', 'city_Millbrae',
#        'city_Milpitas', 'city_Morgan Hill', 'city_Mountain View',
#        'city_Newark', 'city_Oakland', 'city_Pacifica', 'city_Palo Alto',
#        'city_Piedmont', 'city_Pleasanton', 'city_Portola Valley',
#        'city_Redwood City', 'city_San Bruno', 'city_San Carlos',
#        'city_San Francisco', 'city_San Jose', 'city_San Leandro',
# ...

# %%
       'clean_mls_types_detached', 'clean_mls_types_duplex',
       'clean_mls_types_other', 'clean_mls_types_other rental property',

# %%
lr = LinearRegression()
lr.fit(combined_X_train_eng, y_train)
predicted_y_values = lr.predict(combined_X_train_eng)
print('lr version 3')
print('- - - - - - - - - - - - - - - - - - - - - - -')
print('rmse: ', np.sqrt(mean_squared_error(y_train, predicted_y_values)))
print('r2: ', r2_score(y_train, predicted_y_values))
# Out:
# lr version 3
# - - - - - - - - - - - - - - - - - - - - - - -
# rmse:  916.6584667343437
# r2:  0.7211893463501278

# %% [markdown]
# ---
#
# pause to look at residual plot
#
# ---

# %%
combined_X_train_eng_res = combined_X_train_eng.copy()
combined_X_train_eng_res['price'] = y_train

# %%
combined_X_train_eng_res['res'] = lr.predict(combined_X_train_eng_res[combined_X_train_eng_res.columns[:-1]])-combined_X_train_eng_res['price']

# %%
combined_X_train_eng_res = combined_X_train_eng_res.sort_values(['res'])
combined_X_train_eng_res.head(10)
subset_res = combined_X_train_eng_res[['beds', 'sq_footage', 'year_built', 'has_address_2',
       'baths_incl_half', 'walk_score',
       'parking_spots_parking', 'parking_spots_parking_unknown',
       'clean_mls_types_condo', 'clean_mls_types_detached',
       'clean_mls_types_duplex', 'clean_mls_types_other', 'clean_mls_types_townhouse', 'price', 'res']]

# %%
g = sns.lineplot(data = subset_res, x = 'beds', y = 'res');
plt.title('Residual error increases in units with > 4 BRs');
plt.xlabel('Bedrooms');
plt.ylabel('Residuals');

# %%
sns.histplot(data = df, x = 'beds');
plt.title('This dataset includes very few 5 and 6 bedroom rentals.');
plt.xlabel('Bedrooms')
# Out:
# Text(0.5, 0, 'Bedrooms')

# %% [markdown]
# what happens if i set a restraint on my model that it can only take in properties with less than 5 bedrooms?

# %%
combined_X_train_eng_br_filter = combined_X_train_eng.copy()
combined_X_train_eng_br_filter['price'] = y_train
combined_X_train_eng_br_filter = combined_X_train_eng_br_filter[combined_X_train_eng_br_filter.beds < 5]
y_train_br_filter = combined_X_train_eng_br_filter['price']
combined_X_train_eng_br_filter = combined_X_train_eng_br_filter.drop(['price'], axis = 1)
print(combined_X_train_eng.shape[0] - combined_X_train_eng_br_filter.shape[0], 'rows dropped.')
# Out:
# 14 rows dropped.

# %%
lr = LinearRegression()
lr.fit(combined_X_train_eng_br_filter, y_train_br_filter)
predicted_y_values = lr.predict(combined_X_train_eng_br_filter)
print('lr version 5')
print('- - - - - - - - - - - - - - - - - - - - - - -')
print('rmse: ', np.sqrt(mean_squared_error(y_train_br_filter, predicted_y_values)))
print('r2: ', r2_score(y_train_br_filter, predicted_y_values))
# Out:
# lr version 5
# - - - - - - - - - - - - - - - - - - - - - - -
# rmse:  915.261529282722
# r2:  0.7058483256464113

# %% [markdown]
# **filtering out 5 and 6 bedroom units reduced the r^2**

# %%
combined_X_train_eng_res = combined_X_train_eng_br_filter.copy()
combined_X_train_eng_res['price'] = y_train_br_filter
combined_X_train_eng_res[combined_X_train_eng_res.columns[:-1]].shape
# Out:
# (921, 74)

# %%
combined_X_train_eng_res['res'] = lr.predict(combined_X_train_eng_res[combined_X_train_eng_res.columns[:-1]])-combined_X_train_eng_res['price']

# %%
combined_X_train_eng_res = combined_X_train_eng_res.sort_values(['res'])
combined_X_train_eng_res.head(10)
subset_res = combined_X_train_eng_res[['beds', 'sq_footage', 'year_built', 'has_address_2',
       'baths_incl_half', 'walk_score',
       'parking_spots_parking', 'parking_spots_parking_unknown',
       'clean_mls_types_condo', 'clean_mls_types_detached',
       'clean_mls_types_duplex', 'clean_mls_types_other', 'clean_mls_types_townhouse', 'price', 'res']]

# %%
sns.lineplot(data = subset_res, x = 'beds', y = 'res');
plt.title('Residuals after removing 5 and 6 bedroom units');
plt.xlabel('Bedrooms');
plt.ylabel('Residuals');

# %% [markdown]
# ---
#
# lasso/ridge time
#
# ---

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.metrics import r2_score

# %%
def mae(y_true, y_pred):
    return np.mean(np.abs(y_pred - y_true)) 

alphalist = 10**(np.linspace(-4,4,200))
err_vec_val = np.zeros(len(alphalist))
err_vec_train = np.zeros(len(alphalist))

for i,curr_alpha in enumerate(alphalist):

    # note the use of a new sklearn utility: Pipeline to pack
    # multiple modeling steps into one fitting process 
    steps = [('standardize', StandardScaler()), 
             ('ridge', Ridge(alpha = curr_alpha))]

    pipe = Pipeline(steps)
    pipe.fit(combined_X_train_eng.values, y_train)
    
    val_set_pred = pipe.predict(combined_X_train_eng.values)
    err_vec_val[i] = mae(y_train, val_set_pred)

# %%
plt.plot(alphalist, err_vec_val)

# %%
np.min(err_vec_val)
# Out:
# 570.3611164913192

# %%
alphalist[np.argmin(err_vec_val)]
# Out:
# 0.00027682866303920667

# %%
steps = [('standardize', StandardScaler()), 
             ('ridge', Ridge(alpha = 0.0002))]

pipe = Pipeline(steps)
pipe.fit(combined_X_train_eng.values, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('standardize',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('ridge',
#                  Ridge(alpha=0.0002, copy_X=True, fit_intercept=True,
#                        max_iter=None, normalize=False, random_state=None,
#                        solver='auto', tol=0.001))],
#          verbose=False)

# %%
y_train_pred = pipe.predict(combined_X_train_eng)

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.7211893121416773
